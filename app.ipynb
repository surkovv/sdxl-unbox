# %% [markdown]
# ## Unpacking SDXL Turbo, SDXL Base, and Flux
#
# Launch the Gradio demo for any supported model using the shared SAE interface.

# %% [markdown]
# ### Runtime setup
# Enable notebook conveniences and reload packages automatically while iterating.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose a model
# Pick between SDXL Turbo, SDXL Base, or Flux.

# %%
MODEL_ID = "stabilityai/stable-diffusion-xl-base-1.0"  # @param ['stabilityai/sdxl-turbo', 'stabilityai/stable-diffusion-xl-base-1.0', 'black-forest-labs/FLUX.1-schnell']

# %% [markdown]
# ### Load the pipeline, SAEs, and launch the demo
# Utility helpers load the correct pipeline and SAE bundle for the selected model.

# %%
import os
import sys

import torch

sys.path.insert(0, os.getcwd())

from utils.loaders import resolve_dtype, load_pipeline, load_sae_bundle

# %%
dtype = resolve_dtype(MODEL_ID)
pipe = load_pipeline(MODEL_ID, dtype)
saes_dict, means_dict = load_sae_bundle(MODEL_ID, dtype)

print(f"Loaded {MODEL_ID} with dtype {dtype}.")
from app import create_demo
demo = create_demo(pipe, saes_dict, means_dict, use_retrieval=False)
demo.launch(share=True, height=1200)
# Out:
# Fetching 19 files:  16%|█▌        | 3/19 [00:31<02:46, 10.41s/it]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 dtype = resolve_dtype(MODEL_ID)
# ----> 2 pipe = load_pipeline(MODEL_ID, dtype)
#       3 saes_dict, means_dict = load_sae_bundle(MODEL_ID, dtype)
#       5 print(f"Loaded {MODEL_ID} with dtype {dtype}.")
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/utils/loaders.py:38, in load_pipeline(model_id, torch_dtype)
#      35     base_pipe.set_progress_bar_config(disable=True)
#      36     return CachedFluxPipeline(base_pipe)
# ---> 38 pipe = HookedStableDiffusionXLPipeline.from_pretrained(
#      39     model_id,
#      40     torch_dtype=torch_dtype,
#      41     device_map="balanced",
#      42     variant=("fp16" if torch_dtype == torch.float16 else None),
#      43 )
#      44 pipe.set_progress_bar_config(disable=True)
#      45 return pipe
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/SDLens/hooked_sd_pipeline.py:31, in HookedDiffusionAbstractPipeline.from_pretrained(cls, *args, **kwargs)
#      29 @classmethod
#      30 def from_pretrained(cls, *args, **kwargs):
# ---> 31     return cls(cls.parent_cls.from_pretrained(*args, **kwargs))
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/diffusers/pipelines/pipeline_utils.py:833, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     828     if pretrained_model_name_or_path.count("/") > 1:
#     829         raise ValueError(
#     830             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#     831             " is neither a valid local path nor a valid repo id. Please check the parameter."
#     832         )
# --> 833     cached_folder = cls.download(
#     834         pretrained_model_name_or_path,
#     835         cache_dir=cache_dir,
#     836         force_download=force_download,
#     837         proxies=proxies,
#     838         local_files_only=local_files_only,
#     839         token=token,
#     840         revision=revision,
#     841         from_flax=from_flax,
#     842         use_safetensors=use_safetensors,
#     843         use_onnx=use_onnx,
#     844         custom_pipeline=custom_pipeline,
#     845         custom_revision=custom_revision,
#     846         variant=variant,
#     847         dduf_file=dduf_file,
#     848         load_connected_pipeline=load_connected_pipeline,
#     849         **kwargs,
#     850     )
#     851 else:
#     852     cached_folder = pretrained_model_name_or_path
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/diffusers/pipelines/pipeline_utils.py:1627, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1625 # download all allow_patterns - ignore_patterns
#    1626 try:
# -> 1627     cached_folder = snapshot_download(
#    1628         pretrained_model_name,
#    1629         cache_dir=cache_dir,
#    1630         proxies=proxies,
#    1631         local_files_only=local_files_only,
#    1632         token=token,
#    1633         revision=revision,
#    1634         allow_patterns=allow_patterns,
#    1635         ignore_patterns=ignore_patterns,
#    1636         user_agent=user_agent,
#    1637     )
#    1639     cls_name = cls.load_config(os.path.join(cached_folder, "model_index.json")).get("_class_name", None)
#    1640     cls_name = cls_name[4:] if isinstance(cls_name, str) and cls_name.startswith("Flax") else cls_name
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/huggingface_hub/_snapshot_download.py:332, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     330         _inner_hf_hub_download(file)
#     331 else:
# --> 332     thread_map(
#     333         _inner_hf_hub_download,
#     334         filtered_repo_files,
#     335         desc=tqdm_desc,
#     336         max_workers=max_workers,
#     337         # User can use its own tqdm class or the default one from `huggingface_hub.utils`
#     338         tqdm_class=tqdm_class or hf_tqdm,
#     339     )
#     341 if local_dir is not None:
#     342     return str(os.path.realpath(local_dir))
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/Academics/papers/SDXL_SAE/sdxl-unbox/.venv/lib/python3.14/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /opt/homebrew/Cellar/python@3.14/3.14.0/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:639, in Executor.map.<locals>.result_iterator()
#     637 # Careful not to keep a reference to the popped future
#     638 if timeout is None:
# --> 639     yield _result_or_cancel(fs.pop())
#     640 else:
#     641     yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /opt/homebrew/Cellar/python@3.14/3.14.0/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:311, in _result_or_cancel(***failed resolving arguments***)
#     309 try:
#     310     try:
# --> 311         return fut.result(timeout)
#     312     finally:
#     313         fut.cancel()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.0/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:445, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
#     443     return self.__get_result()
# --> 445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     448     raise CancelledError()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.0/Frameworks/Python.framework/Versions/3.14/lib/python3.14/threading.py:369, in Condition.wait(self, timeout)
#     367 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     368     if timeout is None:
# --> 369         waiter.acquire()
#     370         gotit = True
#     371     else:
#
# KeyboardInterrupt:
